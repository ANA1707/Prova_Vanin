# %% [markdown]
# <a href="https://colab.research.google.com/github/ANA1707/Prova_Vanin/blob/main/Prova%2028_09_2024_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importação da Biblioteca

# %%
import numpy as np

# %%
# Gerar alguns dados aleatórios

# %% [markdown]
# # Análise exploratória de dados

# %%
#Iniciar com alguns imports:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# Seaborn interace simples,interface simples  para plotar os gráficos

# %% [markdown]
# Examinar o dataset

# %%
df = pd.read_csv("/content/winemag-data-130k-v2.csv")
df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %% [markdown]
# Funçaõ para mostrar os nomes das colunas

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'country', 'description', 'designation', 'points',
#        'price', 'province', 'region_1', 'region_2', 'taster_name',
#        'taster_twitter_handle', 'title', 'variety', 'winery'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129971 entries, 0 to 129970
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             129971 non-null  int64
#  1   country                129908 non-null  object
#  2   description            129971 non-null  object
#  3   designation            92506 non-null   object
#  4   points                 129971 non-null  int64
#  5   price                  120975 non-null  float64
#  6   province               129908 non-null  object
#  7   region_1               108724 non-null  object
#  8   region_2               50511 non-null   object
#  9   taster_name            103727 non-null  object
#  10  taster_twitter_handle  98758 non-null   object
#  11  title                  129971 non-null  object
#  12  variety                129970 non-null  object
#  13  winery                 129971 non-null  object
# ...

# %% [markdown]
# Comando para fazer uma pré Analise estatistica dos valores numericos

# %%
df.describe()
# Out:
#           Unnamed: 0         points          price
# count  129971.000000  129971.000000  120975.000000
# mean    64985.000000      88.447138      35.363389
# std     37519.540256       3.039730      41.022218
# min         0.000000      80.000000       4.000000
# 25%     32492.500000      86.000000      17.000000
# 50%     64985.000000      88.000000      25.000000
# 75%     97477.500000      91.000000      42.000000
# max    129970.000000     100.000000    3300.000000

# %% [markdown]
# Função para  poder contar quantos vinhos foram avaliados por cada pais

# %%
df["country"].value_counts()
# Out:
# country
# US                        54504
# France                    22093
# Italy                     19540
# Spain                      6645
# Portugal                   5691
# Chile                      4472
# Argentina                  3800
# Austria                    3345
# Australia                  2329
# Germany                    2165
# New Zealand                1419
# South Africa               1401
# Israel                      505
# Greece                      466
# Canada                      257
# Hungary                     146
# Bulgaria                    141
# Romania                     120
# Uruguay                     109
# Turkey                       90
# Slovenia                     87
# Georgia                      86
# England                      74
# Croatia                      73
# Mexico                       70
# Moldova                      59
# Brazil                       52
# Lebanon                      35
# Morocco                      28
# ...

# %% [markdown]
# Comando para  verificar  qausi tipos de uva foram mais  utilizadas na fabricação dos vinhos avaliados

# %%
df["variety"].value_counts()
# Out:
# variety
# Pinot Noir                    13272
# Chardonnay                    11753
# Cabernet Sauvignon             9472
# Red Blend                      8946
# Bordeaux-style Red Blend       6915
#                               ...
# Cabernet Sauvignon-Barbera        1
# Sauvignonasse                     1
# Forcallà                          1
# Meseguera                         1
# Bobal-Cabernet Sauvignon          1
# Name: count, Length: 707, dtype: int64

# %% [markdown]
# ```
# # Isto está formatado como código
# ```
#
# # Limpando os Dados

# %% [markdown]
# Função Para fazer uma cópia do DataFrame

# %%
df1 = df.copy()

# %% [markdown]
# Codigo para remover  as colunas  que não vão precisar usar para analise

# %%
df1 = df1.drop(columns=[coluna for coluna in ["unnamed: 0", "designation", "region_1", "region_2", "taster_name", "taster_twitter_handle"] if coluna in df1.columns]); df1.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#    points  price           province  \
# 0      87    NaN  Sicily & Sardinia
# 1      87   15.0              Douro
# 2      87   14.0             Oregon
# 3      87   13.0           Michigan
# 4      87   65.0             Oregon
#
#                                                title         variety  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# ...

# %% [markdown]
# Ainda temos o problema dos dados ausentes para resolver

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129971 entries, 0 to 129970
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Unnamed: 0   129971 non-null  int64
#  1   country      129908 non-null  object
#  2   description  129971 non-null  object
#  3   points       129971 non-null  int64
#  4   price        120975 non-null  float64
#  5   province     129908 non-null  object
#  6   title        129971 non-null  object
#  7   variety      129970 non-null  object
#  8   winery       129971 non-null  object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 8.9+ MB

# %%
df1 = df1.drop(["unnamed: 0", "designation", "region_1", "region_2", "taster_name", "taster_twitter_handle"], axis=1, errors='ignore')
df1.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#    points  price           province  \
# 0      87    NaN  Sicily & Sardinia
# 1      87   15.0              Douro
# 2      87   14.0             Oregon
# 3      87   13.0           Michigan
# 4      87   65.0             Oregon
#
#                                                title         variety  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129971 entries, 0 to 129970
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Unnamed: 0   129971 non-null  int64
#  1   country      129908 non-null  object
#  2   description  129971 non-null  object
#  3   points       129971 non-null  int64
#  4   price        120975 non-null  float64
#  5   province     129908 non-null  object
#  6   title        129971 non-null  object
#  7   variety      129970 non-null  object
#  8   winery       129971 non-null  object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 8.9+ MB

# %% [markdown]
# Calculo para fazer  na coluna de preço para apresentar dados ausentes

# %%
df1.shape
# Out:
# (129971, 9)

# %%
print("{: .0%}".format(df1["price"].count() / df1.shape[0]))
# Out:
#  93%

# %% [markdown]
# Comando para remover os nulos

# %%
df1 = df1 .dropna(subset=["country", "price","variety"])
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 120915 entries, 1 to 129970
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Unnamed: 0   120915 non-null  int64
#  1   country      120915 non-null  object
#  2   description  120915 non-null  object
#  3   points       120915 non-null  int64
#  4   price        120915 non-null  float64
#  5   province     120915 non-null  object
#  6   title        120915 non-null  object
#  7   variety      120915 non-null  object
#  8   winery       120915 non-null  object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 9.2+ MB

# %% [markdown]
# # Analise exploratoria

# %%
plt.figure(figsize=(10,7))
plt.hist(data=df1, x= 'points',
          bins=np.arange(80, df1['points'].max()+1, 1),
                         color = 'purple')
plt.xlim(80,100)
plt.title('Distribuição dos pontos', fontsize=16)
plt.xlabel('Pontos')
plt.ylabel('Frequência')
# Out:
# Text(0, 0.5, 'Frequência')

# %% [markdown]
# Ver os paises que estão no top 10

# %%
coutntry_top10  = df1["country"].value_counts()[:10]
coutntry_top10
# Out:
# country
# US           54265
# France       17776
# Italy        16914
# Spain         6573
# Portugal      4875
# Chile         4415
# Argentina     3756
# Austria       2799
# Australia     2294
# Germany       2120
# Name: count, dtype: int64

# %% [markdown]
# Gerar um Grafico  com pases no resultado do top 10 dos paises

# %%
plt.figure(figsize=(10,7))
coutntry_top10.plot(kind ='bar', color = 'purple')
plt.title('Numero de classificações de vinhos  por pais', fontsize =16)
plt.xlabel('País')
plt.ylabel('Total de avaliações')
# Out:
# Text(0, 0.5, 'Total de avaliações')

# %% [markdown]
# Quantos paises possuem o vinho de melhor  qualidade conforme as classificações

# %%
melhor_qualidade = df1.groupby("country")['points'].agg("mean")
melhor_qualidade = melhor_qualidade.sort_values(ascending=False)[:10]
# converter em uma serie o Dataframe usando o metódo to_frame()
melhor_qualidade.to_frame().style.background_gradient(cmap='Purples', high=0.5)
# Out:
# <style type="text/css">
# #T_a5144_row0_col0 {
#   background-color: #796eb2;
#   color: #f1f1f1;
# }
# #T_a5144_row1_col0 {
#   background-color: #bebfdd;
#   color: #000000;
# }
# #T_a5144_row2_col0 {
#   background-color: #c0c1de;
#   color: #000000;
# }
# #T_a5144_row3_col0 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_a5144_row4_col0 {
#   background-color: #e7e6f1;
#   color: #000000;
# }
# #T_a5144_row5_col0 {
#   background-color: #efedf5;
#   color: #000000;
# }
# #T_a5144_row6_col0 {
#   background-color: #f3f1f7;
#   color: #000000;
# }
# #T_a5144_row7_col0 {
#   background-color: #faf8fb;
#   color: #000000;
# }
# #T_a5144_row8_col0 {
#   background-color: #fbfafc;
#   color: #000000;
# }
# #T_a5144_row9_col0 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# </style>
# <table id="T_a5144" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %% [markdown]
#  Podemos gerar  um gráfico  desse filtro:

# %%
y = melhor_qualidade.index.to_series()
x = melhor_qualidade.values  # Acessa os valores da Série diretamente

plt.figure(figsize=(10, 7))
plt.xlim(80, 92)
sns.barplot(x=x, y=y, palette='Purples_r')
plt.title('Top 10 média de vinhos de melhor qualidade por país', fontsize=16)
plt.xlabel('Média de pontos')
plt.ylabel('País')
plt.show()
# Out:
# <ipython-input-22-214ba201c80f>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=x, y=y, palette='Purples_r')

# %% [markdown]
# Fazer um filtro para selecionar vinhos que tenham  as classificações mais altas acima de 95

# %%
high_scores = df1[df1["points"]>=95]
high_scores["country"].value_counts()
# Out:
# country
# US              991
# France          509
# Italy           326
# Austria         103
# Portugal         96
# Germany          62
# Spain            51
# Australia        47
# Argentina        11
# Hungary           5
# England           3
# South Africa      3
# Chile             2
# New Zealand       2
# Name: count, dtype: int64

# %% [markdown]
# Criar um grafico para ver  o maximo, minimo e media dos paises

# %%
plt.figure(figsize=(20, 10))
sns.boxplot(data=df1, x='points', y='country', color='purple')
plt.title('Pontos por país', fontsize=16)
plt.xlabel('Pontos')
plt.ylabel('País')
plt.show()

# %% [markdown]
# Investigar o valor dos vinhos nos paises

# %%
average_price = df1.groupby("country")['price'].mean()  # Use 'price' em minúsculas
average_price = average_price.sort_values(ascending=False)
y = average_price.index.to_series()
x = average_price.values

plt.figure(figsize=(12, 8))
sns.barplot(x=x, y=y, palette='Purples_r')
plt.title('Preço médio da garrafa de vinho por país', fontsize=16)
plt.xlabel('Preço Médio ($)')
plt.ylabel('País')
plt.show()
# Out:
# <ipython-input-25-e54becda7de9>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=x, y=y, palette='Purples_r')

# %% [markdown]
# Verificar se o preço está ligado a qualidade do vinho

# %%
plt.figure(figsize=(10, 7))
bins = np.arange(0, df1["price"].max() + 5, 5)
plt.hist(data=df1, x='price', bins=bins, color='purple')
plt.xlim(0, 200)
plt.title('Distribuição dos preços dos vinhos', fontsize=16)
plt.xlabel('Preço ($)')
plt.ylabel('Frequência')
plt.show()

# %% [markdown]
# so o preço

# %%
df1["price"].describe()
# Out:
# count    120915.000000
# mean         35.368796
# std          41.031188
# min           4.000000
# 25%          17.000000
# 50%          25.000000
# 75%          42.000000
# max        3300.000000
# Name: price, dtype: float64

# %% [markdown]
# Distribuição  logaritima

# %%
np.log10(df1["price"].describe())
# Out:
# count    5.082480
# mean     1.548620
# std      1.613114
# min      0.602060
# 25%      1.230449
# 50%      1.397940
# 75%      1.623249
# max      3.518514
# Name: price, dtype: float64

# %% [markdown]
# Utilizando os daods com a  transformação logaritima para o nosso histograma

# %%
plt.figure(figsize=(12, 8))
bins = 10 ** np.arange(0.5, 4.0, 0.05)
ticks = [1, 2, 3, 10, 30, 100, 300, 1000, 3000, 10000]

plt.hist(df1['price'], bins=bins, color='purple', edgecolor='black')
plt.title('Distribuição dos Preços dos Vinhos', fontsize=16)
plt.xscale('log')
plt.xticks(ticks, ticks)
plt.xlabel('Preço ($)')
plt.ylabel('Frequência')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(data=df1, x='price', y='points', color='purple', alpha=0.6)
plt.title('Correlação entre Pontuação e Preço da Garrafa de Vinho', fontsize=16)
plt.xlabel('Preço ($)')
plt.ylabel('Pontuação')
plt.xscale('log')  # Opcional: usar escala logarítmica para o eixo x
plt.show()

# %%
df1[df1["price"] == df1["price"].min()][:1]
# Out:
#       Unnamed: 0 country                                        description  \
# 1987        1987   Spain  Berry and cherry aromas are surprisingly sturd...
#
#       points  price       province  \
# 1987      85    4.0  Central Spain
#
#                                                   title variety       winery
# 1987  Felix Solis 2013 Flirty Bird Syrah (Vino de la...   Syrah  Felix Solis

# %%
df1[df1["price"] == df1["price"].max()][:1]
# Out:
#        Unnamed: 0 country                                        description  \
# 80290       80290  France  This ripe wine shows plenty of blackberry frui...
#
#        points   price  province                                 title  \
# 80290      88  3300.0  Bordeaux  Château les Ormes Sorbet 2013  Médoc
#
#                         variety                    winery
# 80290  Bordeaux-style Red Blend  Château les Ormes Sorbet

# %% [markdown]
# Filtrar vinhos e verificar como eles se pontuam

# %%
top_varieties = df1["variety"].value_counts()[:20]
print(top_varieties)
# Out:
# variety
# Pinot Noir                  12785
# Chardonnay                  11077
# Cabernet Sauvignon           9384
# Red Blend                    8466
# Bordeaux-style Red Blend     5340
# Riesling                     4971
# Sauvignon Blanc              4780
# Syrah                        4086
# Rosé                         3261
# Merlot                       3061
# Zinfandel                    2708
# Malbec                       2593
# Sangiovese                   2377
# Nebbiolo                     2331
# Portuguese Red               2196
# White Blend                  2167
# Sparkling Blend              2027
# Tempranillo                  1788
# Rhône-style Red Blend        1404
# Pinot Gris                   1388
# Name: count, dtype: int64

# %% [markdown]
# Criando um grafico boxplot

# %%
plt.figure(figsize=(20, 12))
sns.boxplot(data=df1,
            x='variety',
            y='points',
            color="purple",
            order=df1["variety"].value_counts().iloc[:20].index)
plt.title('Distribuição de Pontos por Variedade', fontsize=16)
plt.xlabel('Variedade (Uvas)')
plt.ylabel('Pontos')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Descobrir melhor custo beneficio

# %%
# Remover colunas desnecessárias
under_15 = df1.drop(["description", "province", "winery"], axis=1)

# Filtrar vinhos com preço menor ou igual a 15
under_15 = under_15[under_15["price"] <= 15]

# Ordenar pelos pontos e selecionar os 10 melhores
under_15 = under_15.sort_values(by="points", ascending=False)[:10]

# Aplicar estilo com gradiente de cor
under_15.style.background_gradient(cmap='YlOrRd', high=0.5, subset=["price"])
# Out:
# <style type="text/css">
# #T_6b411_row0_col3, #T_6b411_row6_col3, #T_6b411_row7_col3, #T_6b411_row9_col3 {
#   background-color: #febf5a;
#   color: #000000;
# }
# #T_6b411_row1_col3, #T_6b411_row8_col3 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_6b411_row2_col3, #T_6b411_row3_col3, #T_6b411_row4_col3, #T_6b411_row5_col3 {
#   background-color: #f43d25;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6b411" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6b411_level0_col0" class="col_heading level0 col0" >Unnamed: 0</th>
#       <th id="T_6b411_level0_col1" class="col_heading level0 col1" >country</th>
#       <th id="T_6b411_level0_col2" class="col_heading level0 col2" >points</th>
#       <th id="T_6b411_level0_col3" class="col_heading level0 col3" >price</th>
#       <th id="T_6b411_level0_col4" class="col_heading level0 col4" >title</th>
# ...

# %%
# Remover colunas desnecessárias
between_30_and_50 = df1.drop(["description", "province", "winery"], axis=1)

# Filtrar vinhos com preço entre 30 e 50
between_30_and_50 = between_30_and_50[(between_30_and_50["price"] > 30) & (between_30_and_50["price"] <= 50)]

# Ordenar pelos pontos e selecionar os 10 melhores
between_30_and_50 = between_30_and_50.sort_values(by="points", ascending=False)[:10]

# Aplicar estilo com gradiente de cor
between_30_and_50.style.background_gradient(cmap='YlOrRd', high=0.5, subset=["price"])
# Out:
# <style type="text/css">
# #T_a0dc6_row0_col3 {
#   background-color: #feab49;
#   color: #000000;
# }
# #T_a0dc6_row1_col3, #T_a0dc6_row2_col3, #T_a0dc6_row3_col3, #T_a0dc6_row6_col3, #T_a0dc6_row8_col3, #T_a0dc6_row9_col3 {
#   background-color: #f43d25;
#   color: #f1f1f1;
# }
# #T_a0dc6_row4_col3 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_a0dc6_row5_col3 {
#   background-color: #fd9e43;
#   color: #000000;
# }
# #T_a0dc6_row7_col3 {
#   background-color: #fede80;
#   color: #000000;
# }
# </style>
# <table id="T_a0dc6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a0dc6_level0_col0" class="col_heading level0 col0" >Unnamed: 0</th>
#       <th id="T_a0dc6_level0_col1" class="col_heading level0 col1" >country</th>
#       <th id="T_a0dc6_level0_col2" class="col_heading level0 col2" >points</th>
#       <th id="T_a0dc6_level0_col3" class="col_heading level0 col3" >price</th>
# ...

# %%
# Remover colunas desnecessárias
between_15_and_30 = df1.drop(["description", "province", "winery"], axis=1)

# Filtrar vinhos com preço entre 15 e 30
between_15_and_30 = between_15_and_30[(between_15_and_30["price"] > 15) & (between_15_and_30["price"] <= 30)]

# Ordenar pelos pontos e selecionar os 10 melhores
between_15_and_30 = between_15_and_30.sort_values(by="points", ascending=False)[:10]

# Aplicar estilo com gradiente de cor
between_15_and_30.style.background_gradient(cmap='YlOrRd', high=0.5, subset=["price"])
# Out:
# <style type="text/css">
# #T_341f2_row0_col3, #T_341f2_row2_col3 {
#   background-color: #fd7c37;
#   color: #f1f1f1;
# }
# #T_341f2_row1_col3, #T_341f2_row4_col3, #T_341f2_row8_col3 {
#   background-color: #f43d25;
#   color: #f1f1f1;
# }
# #T_341f2_row3_col3, #T_341f2_row7_col3, #T_341f2_row9_col3 {
#   background-color: #fd9740;
#   color: #000000;
# }
# #T_341f2_row5_col3 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_341f2_row6_col3 {
#   background-color: #fc5b2e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_341f2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_341f2_level0_col0" class="col_heading level0 col0" >Unnamed: 0</th>
#       <th id="T_341f2_level0_col1" class="col_heading level0 col1" >country</th>
#       <th id="T_341f2_level0_col2" class="col_heading level0 col2" >points</th>
#       <th id="T_341f2_level0_col3" class="col_heading level0 col3" >price</th>
# ...

# %%
# Remover colunas desnecessárias
between_15_and_30 = df1.drop(["description", "province", "winery"], axis=1)

# Filtrar vinhos com preço entre 15 e 30
between_15_and_30 = between_15_and_30[(between_15_and_30["price"] > 15) & (between_15_and_30["price"] <= 30)]

# Ordenar pelos pontos e selecionar os 50 melhores
top_50_between_15_and_30 = between_15_and_30.sort_values(by="points", ascending=False)[:50]

# Aplicar estilo com gradiente de cor
top_50_between_15_and_30.style.background_gradient(cmap='YlOrRd', high=0.5, subset=["price"])
# Out:
# <style type="text/css">
# #T_347e2_row0_col3, #T_347e2_row2_col3, #T_347e2_row17_col3, #T_347e2_row29_col3, #T_347e2_row44_col3, #T_347e2_row49_col3 {
#   background-color: #fd7034;
#   color: #f1f1f1;
# }
# #T_347e2_row1_col3, #T_347e2_row4_col3, #T_347e2_row8_col3, #T_347e2_row15_col3, #T_347e2_row16_col3, #T_347e2_row21_col3, #T_347e2_row22_col3, #T_347e2_row23_col3, #T_347e2_row28_col3, #T_347e2_row34_col3, #T_347e2_row35_col3, #T_347e2_row36_col3, #T_347e2_row37_col3, #T_347e2_row39_col3, #T_347e2_row42_col3, #T_347e2_row43_col3, #T_347e2_row46_col3 {
#   background-color: #f43d25;
#   color: #f1f1f1;
# }
# #T_347e2_row3_col3, #T_347e2_row7_col3, #T_347e2_row9_col3, #T_347e2_row38_col3 {
#   background-color: #fd8c3c;
#   color: #f1f1f1;
# }
# #T_347e2_row5_col3, #T_347e2_row10_col3, #T_347e2_row19_col3, #T_347e2_row26_col3, #T_347e2_row27_col3 {
#   background-color: #ffefa5;
#   color: #000000;
# }
# #T_347e2_row6_col3, #T_347e2_row33_col3 {
#   background-color: #fc552c;
# ...

# %%
# Remover colunas desnecessárias
above_50 = df1.drop(["description", "province", "winery"], axis=1)

# Filtrar vinhos com preço acima de 50
above_50 = above_50[above_50["price"] > 50]

# Ordenar pelos pontos e selecionar os 50 melhores
top_50_above_50 = above_50.sort_values(by="points", ascending=False)[:50]

# Aplicar estilo com gradiente de cor
top_50_above_50.style.background_gradient(cmap='YlOrRd', high=0.5, subset=["price"])
# Out:
# <style type="text/css">
# #T_5006c_row0_col3, #T_5006c_row3_col3, #T_5006c_row20_col3, #T_5006c_row31_col3, #T_5006c_row39_col3, #T_5006c_row48_col3 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_5006c_row1_col3, #T_5006c_row7_col3 {
#   background-color: #f43d25;
#   color: #f1f1f1;
# }
# #T_5006c_row2_col3, #T_5006c_row37_col3, #T_5006c_row38_col3, #T_5006c_row47_col3 {
#   background-color: #fff4b0;
#   color: #000000;
# }
# #T_5006c_row4_col3, #T_5006c_row9_col3 {
#   background-color: #ffe590;
#   color: #000000;
# }
# #T_5006c_row5_col3 {
#   background-color: #fed976;
#   color: #000000;
# }
# #T_5006c_row6_col3 {
#   background-color: #fede80;
#   color: #000000;
# }
# #T_5006c_row8_col3, #T_5006c_row28_col3 {
#   background-color: #fff2ac;
#   color: #000000;
# }
# #T_5006c_row10_col3, #T_5006c_row26_col3 {
#   background-color: #feb651;
#   color: #000000;
# }
# #T_5006c_row11_col3 {
#   background-color: #ffe48d;
#   color: #000000;
# }
# ...

# %% [markdown]
# fazer um nuvem de palavra, para saber as palavras mais citadas

# %%
from PIL import Image
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# Juntar todas as descrições em uma única string
text = " ".join(description for description in df1["description"])

# Verificar o comprimento do texto
length_of_text = len(text)
print(f"Comprimento do texto: {length_of_text}")

# Gerar a nuvem de palavras
wordcloud = WordCloud(stopwords=STOPWORDS, background_color='white', width=800, height=400).generate(text)

# Exibir a nuvem de palavras
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Remover os eixos
plt.title('Nuvem de Palavras das Descrições dos Vinhos')
plt.show()
# Out:
# Comprimento do texto: 29653210

# %%
from PIL import Image
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# Juntar todas as descrições em uma única string
text = " ".join(description for description in df1["description"])

# Atualizar as stopwords
stopwords = set(STOPWORDS)
stopwords.update(["drink", "now", "wine", "flavor", "flavors"])

# Gerar a nuvem de palavras
wordcloud = WordCloud(stopwords=stopwords,
                      background_color="white",
                      width=2048,
                      height=1024,
                      max_words=1000).generate(text)

# Exibir a nuvem de palavras
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Remover os eixos
plt.title('Nuvem de Palavras das Descrições dos Vinhos')
plt.show()

# %% [markdown]
# # Conclusão

# %% [markdown]
# *   De onde é o melhor vinho?
#     R: A inglaterra é quem  em média produz vinhos soberbos. mas, temos outros paises como França, Italia,EUA, Portugal ou Australia.
# *   O preço do Vinho está relacionado com a qualiade?
#     R:Sim, mas se você saber bem onde escolher  pode encontrar um vinho bararto, e bom.
# *   Certas variedades de uvas são de maior Qualidade?
#     R: Todas as variedades estão na mesma situação. A maior aposta com base no dados é Pinot Noir
# *   Qual é o melhor vinho em cada faixa de preço?
#     R:Encontramos um binho Perfeito para cada orçamento, mas com alguns destaques.
# *   Que palavras são mais utilizadas para descreveer um vinho?
#     R:Finish e palate, aparecem em boa parte das avaliações

# %% [markdown]
# #Minhas 3 perguntas

# %% [markdown]
# *   Quais são os cinco países com mais vinhos avaliados?
# *   Qual a média de pontos dos vinhos por variedade?
# *   Quantos vinhos têm preço acima de 50 dólares?
# *  Qual é a média de pontos dos vinhos por vinícola e quais são as 10 melhores vinícolas?

# %%
top_countries = df1["country"].value_counts().head(5)
print(top_countries)
# Out:
# country
# US          54265
# France      17776
# Italy       16914
# Spain        6573
# Portugal     4875
# Name: count, dtype: int64

# %%
average_points_by_variety = df1.groupby("variety")["points"].mean().sort_values(ascending=False)
print(average_points_by_variety)
# Out:
# variety
# Terrantez             95.000000
# Gelber Traminer       95.000000
# Tinta del Pais        95.000000
# Bual                  94.333333
# Sercial               94.000000
#                         ...
# Shiraz-Tempranillo    82.000000
# Picapoll              82.000000
# Aidani                82.000000
# Airen                 81.666667
# Chancellor            80.500000
# Name: points, Length: 691, dtype: float64

# %%
count_above_50 = df1[df1["price"] > 50].shape[0]
print(f'Número de vinhos acima de 50 dólares: {count_above_50}')
# Out:
# Número de vinhos acima de 50 dólares: 19774

# %%
# Exemplo simples de visualização dos pontos médios por "winery" (vinícola)
viniculas_qualidade = df1.groupby("winery")['points'].mean().sort_values(ascending=False)
top_viniculas = viniculas_qualidade.head(10)
print(top_viniculas)
# Out:
# winery
# Clos de Tart             98.0
# Araujo                   98.0
# Ovid                     97.0
# Gandona                  97.0
# Château Cheval Blanc     97.0
# Château d'Yquem          97.0
# Château Angélus          97.0
# J.L. Chave               97.0
# Salon                    96.8
# Tenuta dell'Ornellaia    96.7
# Name: points, dtype: float64

# %%
# Gráfico de boxplot para visualizar a pontuação por faixa de preço
faixas_precos = pd.cut(df1['price'], bins=[0, 15, 30, 50, 100, 200], labels=["Até 15", "15 a 30", "30 a 50", "50 a 100", "Acima de 100"])

plt.figure(figsize=(12, 6))
sns.boxplot(data=df1, x=faixas_precos, y='points', color='purple')
plt.title('Distribuição da Pontuação por Faixa de Preço')
plt.xlabel('Faixa de Preço ($)')
plt.ylabel('Pontuação')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Conclusão

# %% [markdown]
# A análise dos dados dos vinhos revelou insights interessantes sobre a produção e qualidade. Identificamos que os Estados Unidos, França e Itália são os países com o maior número de vinhos avaliados. Variedades como Terrantez e Gelber Traminer apresentam as melhores pontuações médias, enquanto uma quantidade significativa de vinhos é encontrada na faixa de preço acima de 50 dólares. As vinícolas de destaque, como Clos de Tart e Araujo, demonstram pontuações excepcionais, indicando que a qualidade pode variar amplamente, mesmo dentro de diferentes faixas de preço. O boxplot permitiu visualizar como a pontuação dos vinhos se distribui ao longo de diferentes faixas de preço, oferecendo uma perspectiva valiosa para os consumidores e produtores.
